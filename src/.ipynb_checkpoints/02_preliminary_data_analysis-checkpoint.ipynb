# %%
library(data.table)
library(ggplot2)
library(dplyr)
library(tidyr)
library(pheatmap)
library(stringr)

# %%
# Load required data frames
data <- fread("../data/processed_E-MTAB-4840-query-results.tpms.tsv", sep = "\t")
df_subset <- fread("../data/data_subset.tsv", sep = "\t")

# %% [markdown]
# # Summary statistics for the gene expression values

# %%
# Apply the summary function to each column and store the results in a list
summary_values <- lapply(data[, -c(1,2), with = FALSE], summary)

# Create a new data table to store the summary values
summary_table <- data.table(matrix(ncol = length(summary_values), nrow = 6))

# Set the column names of the summary table to match the samples in the data
setnames(summary_table, names(summary_values))

# Set the row names of the summary table to match the summary statistics
setattr(summary_table, "row.names", names(summary_values[[1]]))

# Fill the summary table with the summary values
for (i in seq_along(summary_values)) {
  summary_table[, i] <- summary_values[[i]]
}

head(summary_table, 5)

# Save the summary table
write.table(summary_table, "../results/eda/data_summary.tsv", sep = "\t", row.names = TRUE)
# Out:
#   10 post conception weeks, basal ganglion
# 1 0.000
# 2 2.000
# 3 3.585
# 4 3.641
# 5 5.129
#   10 post conception weeks, brain fragment 10 post conception weeks, cerebellum
# 1 0.000                                    0.000
# 2 1.585                                    2.000
# 3 3.322                                    3.459
# 4 3.446                                    3.563
# 5 4.954                                    5.000
#   10 post conception weeks, cerebral cortex
# 1 0.000
# 2 2.000
# 3 3.585
# 4 3.639
# 5 5.209
#   10 post conception weeks, choroid plexus
# 1 0.7655
# 2 3.1699
# 3 3.8074
# 4 4.0553
# 5 4.7004
#   10 post conception weeks, diencephalon 10 post conception weeks, forebrain
# 1 0.000                                  0.000
# 2 2.000                                  2.000
# 3 3.585                                  3.700
# 4 3.653                                  3.700
# 5 5.129                                  5.087
#   10 post conception weeks, forebrain and midbrain
# 1 0.000
# 2 2.000
# 3 3.585
# 4 3.624
# 5 5.129
#   10 post conception weeks, hindbrain
# 1 0.000
# 2 1.585
# 3 3.459
# 4 3.526
# 5 5.000
#   10 post conception weeks, medulla oblongata ⋯
# 1 0.000                                       ⋯
# 2 2.000                                       ⋯
# 3 3.585                                       ⋯
# 4 3.661                                       ⋯
# 5 5.044                                       ⋯
#   Carnegie Stage 23, telencephalon Late 8 post conception weeks, basal ganglion
# 1 0.000                            0.000
# 2 2.000                            2.000
# 3 3.459                            3.585
# 4 3.559                            3.572
# 5 5.000                            5.044
#   Late 8 post conception weeks, brain fragment
# 1 0.000
# 2 2.000
# 3 3.585
# 4 3.602
# 5 4.954
#   Late 8 post conception weeks, cerebellum
# 1 0.000
# 2 2.000
# 3 3.585
# 4 3.687
# 5 5.129
#   Late 8 post conception weeks, cerebral cortex
# 1 0.000
# 2 1.585
# 3 3.170
# 4 3.398
# 5 5.087
#   Late 8 post conception weeks, diencephalon
# 1 0.000
# 2 1.585
# 3 3.322
# 4 3.479
# 5 4.954
#   Late 8 post conception weeks, hindbrain
# 1 0.000
# 2 2.000
# 3 3.459
# 4 3.518
# 5 4.954
#   Late 8 post conception weeks, medulla oblongata
# 1 0.000
# 2 2.000
# 3 3.585
# 4 3.615
# 5 5.000
#   Late 8 post conception weeks, midbrain
# 1 0.000
# 2 2.000
# 3 3.459
# 4 3.498
# 5 4.954
#   Late 8 post conception weeks, spinal cord
# 1 0.000
# 2 2.000
# 3 3.700
# 4 3.723
# 5 5.087

# %% [markdown]
# # Visualizing the distribution of gene expression values

# %%
# Melt the data to long format for ggplot2
data_long <- melt(data, id.vars = c("GeneID", "GeneName"))

# Create the plot
plot <- ggplot(data_long, aes(value)) +
  geom_histogram(bins = 50, fill = "blue", alpha = 0.7, color = "black") +
  theme_minimal() +
  theme(plot.background = element_rect(fill = "white")) +  
  labs(x = "Gene Expression Value", y = "Frequency",
       title = "Histogram of Gene Expression Values")

# Save the plot to a file
ggsave("../figures/histogram_gene_expression_values.png", plot)

plot
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# # Generating heatmap

# %%
# Create a color palette for the heatmap
my_palette <- colorRampPalette(c("blue", "white", "red"))(n = 255)

# Computer expression matrix
expression_matrix <- df_subset %>%
  group_by(Region, GeneName) %>%
  summarise(Expression = mean(Expression, na.rm = TRUE), .groups = "drop") %>%
  spread(key = Region, value = Expression)

# Create heatmap and save it directly
pheatmap(
  as.matrix(expression_matrix[,-1]), 
  labels_row = expression_matrix$GeneName,
  color = my_palette,
  cluster_rows = TRUE, 
  cluster_cols = TRUE,
  filename = "../figures/heatmap_gene_region.png",
  width = 10,
  height = 8,
  cellwidth = 20,
  cellheight = 10,
  bg = "white"  
)

# %%
# Create a color palette for the heatmap
my_palette <- colorRampPalette(c("blue", "white", "red"))(n = 255)

# Computer expression matrix
expression_matrix <- df_subset %>%
  group_by(NumericWeeks, GeneName) %>%
  summarise(Expression = mean(Expression, na.rm = TRUE), .groups = "drop") %>%
  spread(key = NumericWeeks, value = Expression)

# Create heatmap and save it directly
pheatmap(
  as.matrix(expression_matrix[,-1]), 
  labels_row = expression_matrix$GeneName,
  color = my_palette,
  cluster_rows = TRUE, 
  cluster_cols = TRUE,
  filename = "../figures/heatmap_gene_weeks.png",
  width = 10,
  height = 8,
  cellwidth = 20,
  cellheight = 10,
  bg = "white"  
)

# %% [markdown]
# # Exploring patterns in gene expression across different brain regions and weeks

# %%
theme_set(theme_gray(base_size = 15))  # increase base font size
options(repr.plot.width = 32, repr.plot.height = 8)  # adjust plot size

df_subset %>%
  ggplot(aes(x = NumericWeeks, y = Expression, color = Region, group = interaction(GeneName, Region))) +
  geom_line() +
  facet_wrap(~GeneName) +
  labs(x = "Gestational Age (Weeks)", 
       y = "Gene Expression", 
       color = "Brain Region", 
       title = "Gene expression patterns across different brain regions and gestational ages")

ggsave("../figures/expression_weeks_vs_region.png", width = 30, height = 5, dpi = 300)
# Out:
# plot without title

# %% [markdown]
# Some insights about the dataset:
# *  The earlier stages of Carnegie (Carnegie 1 to 12) primarily focus on very early embryonic development, such as the formation of the neural tube and major organ systems. These stages may not be as relevant for this dataset, which specifically focuses on gene expression in different brain regions.
# * Carnegie Stage 13 and 23 correspond to approximately 5-6 and early 8 weeks post-conception, respectively.
# * The dataset is only up to 20 weeks post-conception, possibly due to the focus of the study that has collected it.
#
# From the plots, we see:
# * Some genes in certain brain regions have no expression prior to Carnegie Stage 22 (c22 in the plot), which suggests that those genes may not be actively involved in the development of those brain regions during the earlier stages. It could indicate that their expression and contribution to those brain regions occur later in development or in a more limited and specific manner. It would be interesting to understand the specific roles and functions of those genes in brain development and why their expression may be absent or low in those particular brain regions at earlier stages.
# * When expressions for different brain regions in different genes are mostly unchanged over different ages, it suggests stable gene expression patterns throughout development. Peaks and drops in expression for certain genes indicate dynamic regulation and potential involvement in specific developmental processes or critical periods within those brain regions at specific ages.

# %%
install.packages("lme4")
# Out:
# Installing package into ‘/home/pegah/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)

# %%
library(lme4)

# Fit a mixed effects model
model <- lmer(Expression ~ Weeks + Region + (1|GeneName), data = df_subset)

# Print model summary
summary(model)
# Out:
# Correlation matrix not shown by default, as p = 43 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML ['lmerMod']
# Formula: Expression ~ Weeks + Region + (1 | GeneName)
#    Data: df_subset
#
# REML criterion at convergence: 4337.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.1848 -0.4831  0.0115  0.6165  3.5057
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  GeneName (Intercept) 1.676    1.295
#  Residual             1.504    1.226
# Number of obs: 1320, groups:  GeneName, 8
#
# Fixed effects:
#                                     Estimate Std. Error t value
# (Intercept)                         4.656670   0.491732   9.470
# Weeks11 post conception weeks      -0.400153   0.167784  -2.385
# Weeks12 post conception weeks      -0.511553   0.170708  -2.997
# Weeks13 post conception weeks      -0.348225   0.179933  -1.935
# Weeks14 post conception weeks      -0.377041   0.206427  -1.827
# Weeks15 post conception weeks      -0.733344   0.285976  -2.564
# Weeks16 post conception weeks      -0.672998   0.179101  -3.758
# Weeks17 post conception weeks      -0.393898   0.225669  -1.745
# Weeks19 post conception weeks      -0.300221   0.462012  -0.650
# Weeks20 post conception weeks      -0.306054   0.462012  -0.662
# Weeks9 post conception weeks       -0.645009   0.166412  -3.876
# WeeksCarnegie Stage 13             -0.745360   0.340975  -2.186
# WeeksCarnegie Stage 14             -0.625797   0.255317  -2.451
# WeeksCarnegie Stage 15             -0.402696   0.462012  -0.872
# WeeksCarnegie Stage 16             -0.973211   0.338858  -2.872
# WeeksCarnegie Stage 17             -0.569224   0.234095  -2.432
# WeeksCarnegie Stage 18             -0.691823   0.234095  -2.955
# WeeksCarnegie Stage 19             -0.473503   0.285752  -1.657
# WeeksCarnegie Stage 20             -0.502910   0.254137  -1.979
# WeeksCarnegie Stage 21             -0.246064   0.234095  -1.051
# WeeksCarnegie Stage 22             -0.169427   0.171788  -0.986
# WeeksCarnegie Stage 23             -0.268730   0.178507  -1.505
# WeeksLate 8 post conception weeks  -0.331705   0.189850  -1.747
# Regionbrain fragment               -0.462957   0.176691  -2.620
# Regioncerebellum                   -0.349018   0.199720  -1.748
# Regioncerebral cortex              -0.340785   0.185088  -1.841
# Regionchoroid plexus               -1.813654   0.201593  -8.997
# Regiondiencephalon                 -0.008779   0.195565  -0.045
# Regiondiencephalon and midbrain    -0.612654   0.486793  -1.259
# Regionforebrain                    -0.140954   0.196167  -0.719
# Regionforebrain and midbrain       -0.195916   0.469392  -0.417
# Regionforebrain fragment           -0.445951   0.261545  -1.705
# Regionhindbrain                    -0.355375   0.191655  -1.854
# Regionhindbrain fragment           -0.225318   0.469330  -0.480
# Regionhindbrain without cerebellum -0.788754   0.345602  -2.282
# Regionhippocampus                  -0.441761   0.351267  -1.258
# Regionmedulla oblongata            -0.445918   0.207087  -2.153
# Regionmidbrain                     -0.530552   0.185820  -2.855
# Regionpituitary and diencephalon    0.234125   0.345602   0.677
# Regionpons                         -0.460356   0.345322  -1.333
# Regionspinal cord                  -0.445522   0.187620  -2.375
# Regiontelencephalon                -0.377462   0.208767  -1.808
# Regiontemporal lobe                -0.220918   0.203719  -1.084

# %%
# Load the necessary packages
library(lme4)
library(ggplot2)

# Fit a mixed effects model
model <- lmer(Expression ~ Weeks + Region + (1|GeneName), data = df_subset)

# Create a data frame of residuals and fitted values
diag_data <- data.frame(
  Residuals = residuals(model),
  Fitted = fitted(model)
)

# Residuals vs Fitted values plot
ggplot(diag_data, aes(x = Fitted, y = Residuals)) +
  geom_point() +
  geom_smooth(se = FALSE) +
  labs(x = "Fitted values", y = "Residuals", title = "Residuals vs Fitted")

# Histogram of residuals
ggplot(diag_data, aes(x = Residuals)) +
  geom_histogram(binwidth = .5, fill = "white", color = "black") +
  labs(x = "Residuals", y = "Count", title = "Histogram of residuals")

# QQ plot of residuals
ggplot(diag_data, aes(sample = Residuals)) +
  stat_qq() +
  stat_qq_line() +
  labs(title = "QQ Plot of residuals")
# Out:
# `geom_smooth()` using method = 'gam' and formula = 'y ~ s(x, bs = "cs")'
# plot without title
# plot without title
# plot without title
